# %% [markdown]
# # Tesseract OCR — Evaluation & Debug Notebook
# **Author:** Manel Carrillo,
#
# **Mail** manelcarrillomaillo@gmail.com
#
# ## Purpose
# Evaluate Tesseract OCR on document pages (PDF → images) with:
# - Visual inspection (original + preprocessed)
# - OCR text preview
# - Word-level bounding boxes and confidence
# - Quick sweeps over preprocessing + `psm` layouts

# %% [markdown]
# #### Imports

# %%
import os
import fitz
import pytesseract
from IPython.display import display
import matplotlib.pyplot as plt
import pandas as pd
from pytesseract import Output
from pathlib import Path
import numpy as np
from PIL import Image, ImageOps, ImageEnhance

# %% [markdown]
# #### Paths

# %%
BASE_DIR = Path.cwd()  # ...\DocumentAgent\Notebooks
DATA_DIR = BASE_DIR.parent / "data" / "images"

# %% [markdown]
# #### Display Helpers

# %%
def show(img, title=None, figsize=(10, 12)):
    if isinstance(img, (str, Path)):
        img = Image.open(img)
    plt.figure(figsize=figsize)
    cmap = "gray" if img.mode in ["L", "1"] else None
    plt.imshow(img, cmap=cmap)
    plt.axis("off")
    if title:
        plt.title(title)
    plt.show()

def crop(img, x1, y1, x2, y2):
    if isinstance(img, (str, Path)):
        img = Image.open(img)
    return img.crop((x1, y1, x2, y2))

# %%
# Example usage
DEFAULT_IMAGE = DATA_DIR / "page_2.png"
show(DEFAULT_IMAGE, "Original")
show(crop(DEFAULT_IMAGE, 200, 200, 2400, 900), "Zoomed region")

# %% [markdown]
# #### Preprocessing

# %% [markdown]
# OCR quality is highly sensitive to image characteristics.
# These preprocessing steps help Tesseract “see” text more clearly.
#
# -  **Scaling (`scale`)**
#     - Enlarges small text → more pixels per character
#     - Improves character shape recognition (especially scans & PDFs)
#
# -  **Grayscale (`to_gray`)**
#     - Removes color noise
#     - Lets OCR focus only on text intensity, not color
#
# -  **Contrast (`contrast`)**
#     - Makes text stand out from background
#     - Helpful for faded scans or low-quality PDFs
#
# -  **Sharpness (`sharpness`)**
#    - Enhances edges of characters
#    - Improves separation between letters (e.g. `rn` vs `m`)
#
# -  **Thresholding (`threshold`)**
#    - Converts image to pure black & white
#    - Reduces background noise and shadows
#     - Often boosts OCR confidence on clean documents
#
# - **Invert (`invert`)**
#     - Useful for dark-background / white-text documents
#    - Matches Tesseract’s expectation: dark text on light background

# %%
def preprocess(
    image,
    scale=1.5,
    to_gray=True,
    contrast=1.0,
    sharpness=1.0,
    threshold=None,
    invert=False,
):
    if isinstance(image, (str, Path)):
        image = Image.open(image)

    img = image

    # Scale up )
    if scale != 1.0:
        w, h = img.size
        img = img.resize((int(w * scale), int(h * scale)), Image.Resampling.LANCZOS)

    # Grayscale
    if to_gray:
        img = ImageOps.grayscale(img)

    # Contrast / sharpness 
    if contrast != 1.0:
        img = ImageEnhance.Contrast(img).enhance(contrast)
    if sharpness != 1.0:
        img = ImageEnhance.Sharpness(img).enhance(sharpness)

    # invert
    if invert:
        img = ImageOps.invert(img) if img.mode == "L" else ImageOps.invert(img.convert("L"))

    # Threshold (binarization)
    if threshold is not None:
        img = img.point(lambda p: 255 if p > threshold else 0)

    return img

PRESETS = {
    "raw": dict(scale=1.0, to_gray=False, contrast=1.0, sharpness=1.0, threshold=None, invert=False),
    "gray+scale": dict(scale=1.5, to_gray=True, contrast=1.0, sharpness=1.0, threshold=None, invert=False),
    "thr_170": dict(scale=1.5, to_gray=True, contrast=1.1, sharpness=1.2, threshold=170, invert=False),
    "thr_200": dict(scale=1.5, to_gray=True, contrast=1.2, sharpness=1.2, threshold=200, invert=False),
}

# %% [markdown]
# ### OCR functions
#
# - **`ocr_text`**
#     - Extracts the raw OCR text from an image
#     - Uses Tesseract with configurable **OEM** (engine) and **PSM** (page layout mode)
#
# - **`ocr_data`**
#     - Returns word-level OCR output as a structured DataFrame
#     - Includes text, bounding box coordinates and confidence scores
#     - Filters empty tokens and invalid confidence values
#
# -  **`draw_boxes`**
#      - Draws bounding boxes around detected words
#      - Filters by minimum confidence (`conf_min`)
#      - Helps visually inspect:
#           - missed text
#           - false positives
#           - alignment and layout errors
#
# -  **`summarize_conf`**
#     - Computes simple confidence statistics:
#         - number of detected words
#         - mean / median confidence
#         - lower and upper confidence percentiles

# %%
def ocr_text(img, lang="eng", psm=6, oem=3):
    if isinstance(img, (str, Path)):
        img = Image.open(img)
    config = f"--oem {oem} --psm {psm}"
    return pytesseract.image_to_string(img, lang=lang, config=config)

def ocr_data(img, lang="eng", psm=6, oem=3):
    if isinstance(img, (str, Path)):
        img = Image.open(img)
    config = f"--oem {oem} --psm {psm}"
    df = pytesseract.image_to_data(img, lang=lang, config=config, output_type=Output.DATAFRAME)
    df = df.dropna(subset=["text"])
    df["text"] = df["text"].astype(str).str.strip()
    df["conf"] = pd.to_numeric(df["conf"], errors="coerce")
    df = df.dropna(subset=["conf"])
    df = df[df["text"] != ""]
    return df

def draw_boxes(img, df, conf_min=60, figsize=(12, 14)):
    if isinstance(img, (str, Path)):
        img = Image.open(img)
    img_np = np.array(img.convert("RGB"))

    plt.figure(figsize=figsize)
    plt.imshow(img_np)
    plt.axis("off")
    ax = plt.gca()

    dff = df[df["conf"] >= conf_min].copy()
    for _, r in dff.iterrows():
        x, y, w, h = int(r["left"]), int(r["top"]), int(r["width"]), int(r["height"])
        ax.add_patch(plt.Rectangle((x, y), w, h, fill=False, linewidth=1))
        ax.text(x, y - 2, f'{r["conf"]:.0f}', fontsize=8)

    plt.title(f"Boxes (conf ≥ {conf_min}) | words: {len(dff)}")
    plt.show()

def summarize_conf(df):
    if df.empty:
        return {"words": 0, "conf_mean": None, "conf_median": None, "conf_p10": None, "conf_p90": None}
    return {
        "words": int(len(df)),
        "conf_mean": float(df["conf"].mean()),
        "conf_median": float(df["conf"].median()),
        "conf_p10": float(df["conf"].quantile(0.10)),
        "conf_p90": float(df["conf"].quantile(0.90)),
    }

# %% [markdown]
# #### Single Page evaluator
#
# This function runs a **complete OCR evaluation workflow** on a single document page.
#
# It combines:
# - preprocessing
# - OCR text extraction
# - word-level analysis
# - visual inspection
#
# into a single, reproducible call.

# %%
def evaluate_page(
    image_path,
    preset="thr_170",
    lang="eng",
    psm=6,
    oem=3,
    conf_min=0,
    text_preview=666200,
    show_preprocessed=True,
    show_overlay=True,
):
    params = PRESETS[preset]
    img = Image.open(image_path)

    show(img, f"Original — {Path(image_path).name}")

    img_proc = preprocess(img, **params)
    if show_preprocessed:
        show(img_proc, f"Preprocessed preset='{preset}' | psm={psm}")

    df = ocr_data(img_proc, lang=lang, psm=psm, oem=oem)
    stats = summarize_conf(df)

    txt = ocr_text(img_proc, lang=lang, psm=psm, oem=oem)

    print("Stats:", stats)
    print("\nOCR Output (preview):\n--------------------\n")
    print(txt[:text_preview])

    if show_overlay:
        draw_boxes(img_proc, df, conf_min=conf_min)

    return img_proc, df, txt

# %% [markdown]
# ### OCR configuration sweep (presets × PSM)
#
# This function performs a **systematic sweep** over multiple OCR configurations
# to identify which combination works best for a given document page.

# %%
def sweep(image_path, presets=None, psms=None, lang="eng", oem=3):
    if presets is None:
        presets = list(PRESETS.keys())
    if psms is None:
        psms = [3, 4, 6, 11]

    rows = []
    base_img = Image.open(image_path)

    for preset in presets:
        img_proc = preprocess(base_img, **PRESETS[preset])
        for psm in psms:
            df = ocr_data(img_proc, lang=lang, psm=psm, oem=oem)
            stats = summarize_conf(df)
            rows.append({
                "image": Path(image_path).name,
                "preset": preset,
                "psm": psm,
                **stats
            })

    out = pd.DataFrame(rows)
    # simple scoring: reward lots of words + high mean conf
    out["score"] = out["words"] * (out["conf_mean"].fillna(0) / 100.0)
    out = out.sort_values("score", ascending=False).reset_index(drop=True)
    return out

# %%
def compare_grid(image_path, configs, figsize=(14, 10)):
    img = Image.open(image_path)
    n = len(configs)
    cols = 2
    rows = (n + cols - 1) // cols

    plt.figure(figsize=figsize)
    for i, cfg in enumerate(configs, 1):
        preset = cfg["preset"]
        psm = cfg["psm"]
        img_proc = preprocess(img, **PRESETS[preset])

        plt.subplot(rows, cols, i)
        plt.imshow(img_proc, cmap="gray")
        plt.axis("off")
        plt.title(f"preset={preset} | psm={psm}")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## EXECUTIONS

# %%
PATH1 = DATA_DIR / "page_1.png"
PATH2 = DATA_DIR / "page_2.png"
PATH3 = DATA_DIR / "page_3.png"
PATH4 = DATA_DIR / "page_7.png"
PATH5 = DATA_DIR / "TFG1.png"

# %% [markdown]
# ## Execution 1 — Simple text-only page
#
# **Document characteristics**
# - Single paper page
# - Text-only content
# - No charts, tables or complex layouts
# - Standard academic-style formatting
#
# **Objective**
# Evaluate baseline OCR performance on a clean document page without structural complexity.

# %%
evaluate_page(PATH1, preset="thr_170", psm=6)
# Out:
# Stats: {'words': 580, 'conf_mean': 91.3408505, 'conf_median': 96.14685850000001, 'conf_p10': 90.42850899999999, 'conf_p90': 96.8723319}
#
# OCR Output (preview):
# --------------------
#
# Hybrid Linear Attention Done Right:
# Efficient Distillation and Effective Architectures for Extremely Long Contexts
# Yingfa Chen“! Zhen Leng Thai”! Zihan Zhou? Zhu Zhang’ Xingyu Shen !
# Shuo Wang! Chaojun Xiao! Xu Han! Zhiyuan Liu!
# 'NLP Group, DCST, IAI, BNRIST, Tsinghua University, Beijing, China ”OpenBMB
# {chenyingfal1999, thaizhenleng123}@gmail.com
# wangshuo.thu@gmail.com, han-xu@tsinghua.edu.cn
# \O
# N
# < Abstract 1. Introduction
# = Transformer-based language models (Vaswani et al., 2017)
# S rely on softmax attention blocks, which have a quadratic
# Hybrid Transformer architectures, which com- complexity with respect to the context length, making
# <a bine softmax attention blocks and recurrent neu- them prohibitively expensive for long contexts. In con-
# ral networks (RNNs), have shown a desirable trast, recurrent neural networks (RNNs) such as linear atten-
# — performance-throughput tradeoff for long-context tion (Katharopoulos et al., 2020) and state space models (Gu
# —| modeling, but their adoption and studies are hin- & Dao, 2024) are much faster for long-context modeling due
# UO dered by the prohibitive cost of large-scale pre- to their linear complexity. However, pure RNN models with
# Nn training from scratch. Some recent studies have fixed-size states generally underperform softmax attention,
# DY, shown that pre-trained softmax attention blocks particularly on recall-intensive tasks (Jelassi et al., 2024;
# can be converted into RNN blocks through pa- Yang et al., 2025b). To address this gap, there is a surge
# — rameter transfer and knowledge distillation. How- in interest in hybrid architectures that interleave attention
# > ever, these transfer methods require substantial and RNN layers’, achieving a favorable tradeoff between
# v4 amounts of training data (more than 10B tokens), model performance and inference throughput (Lieber et al.,
# — and the resulting hybrid models also exhibit poor 2024; MiniMax et al., 2025; Qwen, 2025; Kimi et al., 2025;
# AN long-context performance, which is the scenario NVIDIA et al., 2025).
# N where hybrid models enjoy significant inference ;
# _ speedups over Transformer-based models. In Hybrid architectures are typically pre-trained from scratch
# oO this paper, we present HALO (Hybrid Attention at a large scale (Qwen, 2025; NVIDIA et al., 2025), placing
# No) via Layer Optimization), a pipeline for distill- them beyond the reach of most academic research teams.
# NA ing Transformer models into RNN-attention hy- Hence, some works focus on distilling pre-trained Trans-
# SS brid models. We then present HypeNet, a hy- former models into hybrid architectures (Gu et al., 2025;
# _— brid architecture with superior length generaliza- Hoshino et al., 2025; Wang et al., 2025b). These distil-
# >< tion enabled by a novel position encoding scheme lation methods use far fewer training tokens and produce
# =| (named HyPE) and various architectural modifica- hybrid models that are comparable to their Transformer
# tions. We convert the Qwen3 series into HypeNet counterparts on various common-sense reasoning (CSR)
# using HALO, achieving performance comparable tasks. Although distilled hybrid models typically underper-
# to the original Transformer models while enjoying form those trained from scratch, they are valuable since they
# superior long-context performance and efficiency. allow teams without resources to scale up pre-training to
# The conversion requires just 2.3B tokens, less validate research ideas.
# than 0.01% of their pre-training data’. However, these distillation methods still suffer from two
# critical limitations. (1) Most distillation methods still re-
# quire tens to hundreds of billions of training tokens, which
# is still out of reach for most teams in academia. (2) While
# |The code and model checkpoints can be found at: https: // *We hereby use hybrid architectures/models to refer to archi-
# github .com/THUNLP/hybrid-linear—attention. tectures/models that consist of softmax attention and RNN layers.
# “Equal contributions.
# 1
# (<PIL.Image.Image image mode=L size=3825x4950>,
#       level  page_num  block_num  par_num  line_num  word_num  left   top  \
#  4        5         1          1        1         1         1  1156   569
#  5        5         1          1        1         1         2  1458   569
#  6        5         1          1        1         1         3  1739   569
#  7        5         1          1        1         1         4  2125   570
#  8        5         1          1        1         1         5  2348   569
#  ..     ...       ...        ...      ...       ...       ...   ...   ...
#  625      5         1          1        1        46        10  3106  4350
#  626      5         1          1        1        46        11  3238  4349
#  628      5         1          1        1        47         1   428  4428
#  629      5         1          1        1        47         2   594  4430
#  631      5         1          1        1        48         1  1857  4582
#
#       width  height       conf            text
#  4      277      81  95.795219          Hybrid
#  5      257      64  95.935661          Linear
#  6      362      64  95.372940       Attention
#  7      196      63  95.372940            Done
#  8      235      81  96.250137          Right:
#  ..     ...     ...        ...             ...
#  625    116      38  92.096077             RNN
#  626    142      51  96.542770         layers.
#  628    149      53  87.992722          “Equal
#  629    303      39  96.809082  contributions.
#  631     17      43  72.689362               1
#
#  [580 rows x 12 columns],
#  "Hybrid Linear Attention Done Right:\nEfficient Distillation and Effective Architectures for Extremely Long Contexts\nYingfa Chen“! Zhen Leng Thai”! Zihan Zhou? Zhu Zhang’ Xingyu Shen !\nShuo Wang! Chaojun Xiao! Xu Han! Zhiyuan Liu!\n'NLP Group, DCST, IAI, BNRIST, Tsinghua University, Beijing, China ”OpenBMB\n{chenyingfal1999, thaizhenleng123}@gmail.com\nwangshuo.thu@gmail.com, han-xu@tsinghua.edu.cn\n\\O\nN\n< Abstract 1. Introduction\n= Transformer-based language models (Vaswani et al., 2017)\nS rely on softmax attention blocks, which have a quadratic\nHybrid Transformer architectures, which com- complexity with respect to the context length, making\n<a bine softmax attention blocks and recurrent neu- them prohibitively expensive for long contexts. In con-\nral networks (RNNs), have shown a desirable trast, recurrent neural networks (RNNs) such as linear atten-\n— performance-throughput tradeoff for long-context tion (Katharopoulos et al., 2020) and state space models (Gu\n—| modeling, but their adoption and studies are hin- & Dao, 2024) are much faster for long-context modeling due\nUO dered by the prohibitive cost of large-scale pre- to their linear complexity. However, pure RNN models with\nNn training from scratch. Some recent studies have fixed-size states generally underperform softmax attention,\nDY, shown that pre-trained softmax attention blocks particularly on recall-intensive tasks (Jelassi et al., 2024;\ncan be converted into RNN blocks through pa- Yang et al., 2025b). To address this gap, there is a surge\n— rameter transfer and knowledge distillation. How- in interest in hybrid architectures that interleave attention\n> ever, these transfer methods require substantial and RNN layers’, achieving a favorable tradeoff between\nv4 amounts of training data (more than 10B tokens), model performance and inference throughput (Lieber et al.,\n— and the resulting hybrid models also exhibit poor 2024; MiniMax et al., 2025; Qwen, 2025; Kimi et al., 2025;\nAN long-context performance, which is the scenario NVIDIA et al., 2025).\nN where hybrid models enjoy significant inference ;\n_ speedups over Transformer-based models. In Hybrid architectures are typically pre-trained from scratch\noO this paper, we present HALO (Hybrid Attention at a large scale (Qwen, 2025; NVIDIA et al., 2025), placing\nNo) via Layer Optimization), a pipeline for distill- them beyond the reach of most academic research teams.\nNA ing Transformer models into RNN-attention hy- Hence, some works focus on distilling pre-trained Trans-\nSS brid models. We then present HypeNet, a hy- former models into hybrid architectures (Gu et al., 2025;\n_— brid architecture with superior length generaliza- Hoshino et al., 2025; Wang et al., 2025b). These distil-\n>< tion enabled by a novel position encoding scheme lation methods use far fewer training tokens and produce\n=| (named HyPE) and various architectural modifica- hybrid models that are comparable to their Transformer\ntions. We convert the Qwen3 series into HypeNet counterparts on various common-sense reasoning (CSR)\nusing HALO, achieving performance comparable tasks. Although distilled hybrid models typically underper-\nto the original Transformer models while enjoying form those trained from scratch, they are valuable since they\nsuperior long-context performance and efficiency. allow teams without resources to scale up pre-training to\nThe conversion requires just 2.3B tokens, less validate research ideas.\nthan 0.01% of their pre-training data’. However, these distillation methods still suffer from two\ncritical limitations. (1) Most distillation methods still re-\nquire tens to hundreds of billions of training tokens, which\nis still out of reach for most teams in academia. (2) While\n|The code and model checkpoints can be found at: https: // *We hereby use hybrid architectures/models to refer to archi-\ngithub .com/THUNLP/hybrid-linear—attention. tectures/models that consist of softmax attention and RN ...

# %% [markdown]
# ### Observations
# Despite good overall OCR confidence, several qualitative issues are observed:
#
# - **Multi-column layout mixing**
#   - Text from the left and right columns is interleaved.
#   - Lines from the *Abstract* are followed by lines from the *Introduction*, breaking reading order.
#
# - **Layout noise interpreted as text**
#   - Margin elements, separators and decorative lines are detected as characters.
#   - Results in isolated letters and symbols with no semantic meaning.
#
# -  **Broken words and hyphenation artifacts**
#     - Words split across lines in the original PDF remain fragmented.
#     - Affects readability and lexical consistency.
#
# -  **Malformed punctuation and symbols**
#     - Superscripts, footnotes and special symbols are incorrectly rendered.
#     - Common in author lists, affiliations and references.
#
# -  **Loss of document structure**
#    - Section boundaries (e.g. Abstract vs Introduction) are not preserved.
#    - Paragraph-level organization is partially flattened.
#
# -  **Risk for downstream LLM usage**
#     - Mixed sections and noisy tokens can confuse language models.
#     - Additional layout-aware preprocessing or cleaning is required before LLM ingestion.

# %%
evaluate_page(PATH2, preset="thr_170", psm=6)
# Out:
# Stats: {'words': 739, 'conf_mean': 82.71566936535861, 'conf_median': 95.097374, 'conf_p10': 33.145214599999996, 'conf_p90': 96.7228618}
#
# OCR Output (preview):
# --------------------
#
# Hybrid Linear Attention Done Right
# More memory- Fasterand | ,, 4150 y, ~@- Qwen3
# wo efficient _---7*® o @ better a v -E- HypeNet
# Y 70 Z ® 2707 8 ee Es ’
# s a ae ~~ Ng 3 £ 100 a 3.0% _--#
# 5 604,” °° 5 60 ‘e arn £5 v aa
# = |" P E \\ ~m) oS sof et yeti”
# 10 20 30 40 50 60 70 10 20 30 40 50 0 256K 512K 768K 1M
# Memory (GB) Throughput (tokens/s) Context Length
# Figure 1. Left & center: the performance-efficiency tradeoff of our model, HypeNet, versus the Qwen3 series, measured with 128K
# context length and BFloat16 precision. Right: the time per output token of the 1.7B models across different context lengths. For 1M
# context length, the Qwen3 model runs out of GPU memory. HypeNet is converted from Qwen3 using our distillation procedure, HALO,
# and has better performance-efficiency tradeoff than Qwen3.
# the resulting hybrid models have short-context performance rare | hos atention to hybrid cistilation methods and their
# comparable to Transformer models, they exhibit severe per- Felease date and’ training tokens required.
# formance degradation on long-context tasks, which is pre- “Method . ©6Date.6©.©6 Tokens
# cisely the scenario where they are preferred over Trans- i =O —
# former models Mamba-in-the-Llama (Wang et al.) Aug. 2024 20B
# , SMART (Yang et al.) May 2025 >7B
# To address these challenges, we first propose HALO (Hy- RAD (Hoshino et al.) May 2025 20B
# . . . ee Jet-Nemotron (Gu et al.) Aug. 2025 400B
# brid Attention via Layer Optimization), a novel cross KL-LS (Liet al.) Dec. 2025 5B
# architecture distillation procedure for converting pre-trained —————————————————
# Transformer models into hybrid models. Notably, HALO in- HALO (ours) Jan. 2026 2.3B
# volves an efficient attention layer selection method for deter-
# mining which attention layers to keep unconverted to ensure
# the best long-context performance. Then, we propose Hy- 2. Related Works
# enanan eneoeine eine a Mein moans scheme RNN-Attention Hybrid Models State-of-the-art hybrid
# nb lech toon ee tuition OH PE y designed for models with up to hundreds of billions of parameters have
# YORE areOrectures. A a@cavton tO MY" bs WE Propose a exhibited performance comparable to standard Transform-
# vblat of architectural Parveen va with caren ers on both commonsense reasoning and recall-intensive
# ablation experimen son mo eis With Over parame TS. tasks (e.g., needle-in-a-haystack (NIAH) (Hsieh et al.,
# The combination of these improvements results in HypeNet, 2024)) while being more efficient for processing long con-
# a SeTIes er hybrig modes converted “om ue owen? fr texts (Lieber et al., 2024; MiniMax et al., 2025; Qwen, 2025;
# Ne ewan a ie, pertormance-througnput tradeout, = kimi et al., 2025; NVIDIA et al., 2025). Despite their im-
# as SHOWN Mh higure -- pressive performance, there are rather few publicly available
# Our contributions can be summarized as follows: hybrid models with frontier-level performance, because pre-
# training from scratch is prohibitively expensive for most
# » We develop a novel cross-architecture distillation pro- teams. To avoid this training cost, we focus on distilling
# P : P pre-trained Transformer models into hybrid models.
# cedure that converts Transformer models into attention-
# RNN hybrid models using fewer than 3B tokens, Position E sag in Hvbrid Model RoPE
# thereby significantly improving the model’s efficiency osition Encoding in Hybrid Models Current, O" (Su
# in long-context scenarios et al., 2023) has become the de facto standard position en-
# coding (PE) for Transformer models (Yang et al., 2025a;
# . Grattafiori et al., 2024). On the other hand, RNNs usually
# ° We present HYPE. a res HO a encode positional information through decay/transition ma-
# scheme that combines Ro u et al. an
# ae trices, and do not employ RoPE (Dao & Gu, 2024; Yang
# NoPE (Kazemnejad et al., 2023), designed for hybrid et al., 2025b). This has remained the case for hybrid models,
# models. Coupled with an attention scaling mechanism, which means attention layers adopt RoPE while RNN lay-
# HyPE achieves superior length generalization. ers do not (i.e., RNNs use NoPE) (Qwen, 2025; MiniMax
# et al., 2025). Recently, SWAN-GPT (Puvvada et al., 2025)
# ¢ Based on HyPE, we propose HypeNet, a novel hybrid has shown promising long-context generalization by com-
# architecture that incorporates multiple architecturalim- —_ bining RoPE in sliding window attention layers and NoPE
# provements when converting from a pre-trained Trans- _in full attention layers, but it is not a hybrid model. Con-
# former model. current to this paper, Kimi-Linear (Kimi et al., 2025) has
# 2
# (<PIL.Image.Image image mode=L size=3825x4950>,
#       level  page_num  block_num  par_num  line_num  word_num  left   top  \
#  4        5         1          1        1         1         1  1427   298
#  5        5         1          1        1         1         2  1615   298
#  6        5         1          1        1         1         3  1791   298
#  7        5         1          1        1         1         4  2032   299
#  8        5         1          1        1         1         5  2172   298
#  ..     ...       ...        ...      ...       ...       ...   ...   ...
#  794      5         1          1        1        57         9  2975  4433
#  795      5         1          1        1        57        10  3040  4426
#  796      5         1          1        1        57        11  3135  4426
#  797      5         1          1        1        57        12  3300  4426
#  799      5         1          1        1        58         1  1851  4582
#
#       width  height       conf       text
#  4      173      51  96.450287     Hybrid
#  5      161      41  96.269180     Linear
#  6      226      41  95.930733  Attention
#  7      123      40  95.916931       Done
#  8      132      52  95.924126      Right
#  ..     ...     ...        ...        ...
#  794     45      36  93.175293         et
#  795     73      51  91.219284       al.,
#  796    144      53  96.030258      2025)
#  797     81      44  96.030258        has
#  799     28      43  96.940353          2
#
#  [739 rows x 12 columns],
#  'Hybrid Linear Attention Done Right\nMore memory- Fasterand | ,, 4150 y, ~@- Qwen3\nwo efficient _---7*® o @ better a v -E- HypeNet\nY 70 Z ® 2707 8 ee Es ’\ns a ae ~~ Ng 3 £ 100 a 3.0% _--#\n5 604,” °° 5 60 ‘e arn £5 v aa\n= |" P E \\\\ ~m) oS sof et yeti”\n10 20 30 40 50 60 70 10 20 30 40 50 0 256K 512K 768K 1M\nMemory (GB) Throughput (tokens/s) Context Length\nFigure 1. Left & center: the performance-efficiency tradeoff of our model, HypeNet, versus the Qwen3 series, measured with 128K\ncontext length and BFloat16 precision. Right: the time per output token of the 1.7B models across different context lengths. For 1M\ncontext length, the Qwen3 model runs out of GPU memory. HypeNet is converted from Qwen3 using our distillation procedure, HALO,\nand has better performance-efficiency tradeoff than Qwen3.\nthe resulting hybrid models have short-context performance rare | hos atention to hybrid cistilation methods and their\ncomparable to Transformer models, they exhibit severe per- Felease date and’ training tokens required.\nformance degradation on long-context tasks, which is pre- “Method . ©6Date.6©.©6 Tokens\ncisely the scenario where they are preferred over Trans- i =O —\nformer models Mamba-in-the-Llama (Wang et al.) Aug. 2024 20B\n, SMART (Yang et al.) May 2025 >7B\nTo address these challenges, we first propose HALO (Hy- RAD (Hoshino et al.) May 2025 20B\n. . . ee Jet-Nemotron (Gu et al.) Aug. 2025 400B\nbrid Attention via Layer Optimization), a novel cross KL-LS (Liet al.) Dec. 2025 5B\narchitecture distillation procedure for converting pre-trained —————————————————\nTransformer models into hybrid models. Notably, HALO in- HALO (ours) Jan. 2026 2.3B\nvolves an efficient attention layer selection method for deter-\nmining which attention layers to keep unconverted to ensure\nthe best long-context performance. Then, we propose Hy- 2. Related Works\nenanan eneoeine eine a Mein moans scheme RNN-Attention Hybrid Models State-of-the-art hybrid\nnb lech toon ee tuition OH PE y designed for models with up to hundreds of billions of parameters have\nYORE areOrectures. A a@cavton tO MY" bs WE Propose a exhibited performance comparable to standard Transform-\nvblat of architectural Parveen va with caren ers on both commonsense reasoning and recall-intensive\nablation experimen son mo eis With Over parame TS. tasks (e.g., needle-in-a-haystack (NIAH) (Hsieh et al.,\nThe combination of these improvements results in HypeNet, 2024)) while being more efficient for processing long con-\na SeTIes er hybrig modes converted “om ue owen? fr texts (Lieber et al., 2024; MiniMax et al., 2025; Qwen, 2025;\nNe ewan a ie, pertormance-througnput tradeout, = kimi et al., 2025; NVIDIA et al., 2025). Despite their im-\nas SHOWN Mh higure -- pressive performance, there are rather few publicly available\nOur contributions can be summarized as follows: hybrid models with frontier-level performance, because pre-\ntraining from scratch is prohibitively expensive for most\n» We develop a novel cross-architecture distillation pro- teams. To avoid this training cost, we focus on distilling\nP : P pre-trained Transformer models into hybrid models.\ncedure that converts Transformer models into attention-\nRNN hybrid models using fewer than 3B tokens, Position E sag in Hvbrid Model RoPE\nthereby significantly improving the model’s efficiency osition Encoding in Hybrid Models Current, O" (Su\nin long-context scenarios et al., 2023) has become the de facto standard position en-\ncoding (PE) for Transformer models (Yang et al., 2025a;\n. Grattafiori et al., 2024). On the other hand, RNNs usually\n° We present HYPE. a res HO a encode positional information through decay/transition ma-\nscheme that combines Ro u et al. an\nae trices, and do not employ RoPE (Dao & Gu, 2024; Yang\nNoPE (Kazemnejad et al., 2023), designed for hybrid et al., 2025b). This has remained the case for hybrid models,\nmodels. Coupled with an attention scaling mechanism, which means attention  ...

# %% [markdown]
# ### Observations
#
# When processing pages containing graphs and tables, the following issues are observed:
#
# - **Charts and plots are not semantically interpreted**
#   - Only scattered labels or numbers are extracted.
#   - Visual relationships (axes, trends, legends) are completely lost.
#
# - **Tables are poorly detected**
#   - Rows and columns are not preserved.
#   - Table content is flattened into fragmented, unordered text.
#   - Numeric values may be merged with unrelated text.
#
# - **High amount of visual noise**
#   - Grid lines, borders and separators are misinterpreted as characters.
#   - Results in corrupted text that mixes content from figures, tables and surrounding paragraphs.

# %%
evaluate_page(PATH3, preset="thr_170", psm=6)
# Out:
# Stats: {'words': 767, 'conf_mean': 84.99906782529335, 'conf_median': 96.033791, 'conf_p10': 43.42148, 'conf_p90': 96.8849336}
#
# OCR Output (preview):
# --------------------
#
# Hybrid Linear Attention Done Right
# adopted NoPE in both attention and RNN layers. Incontrast, | Softmax Attention Layers In Transformer, the mixer
# our model employs a novel PE scheme and achieves better —_ layer uses softmax attention, which can be written as*
# long-context performance than typical PE methods found in
# existing hybrid models. Q=XW,, K=XW;, V=XW,,
# 1 (3)
# Y = soft —QK'oM)vw}
# Distilling Transformers into Hybrid Models Many sommes (. /dy, QK' © ) °°
# works focus on converting Transformers into pure RNN
# models via distillation (Kasai et al., 2021; Bick et al., 2025; | where W,,W;,W,,W. © R**% are learnable param-
# Zhang et al., 2025; Goldstein et al., 2025), but converting eters, and M is the attention mask. We use row-vector
# Transformers into hybrid models remains underexplored. _tepresentation, so x'x denotes an outer product.
# When distilling into hybrids, choosing which attention layer
# to convert to RNN is critical for maintaining performance, | Modern RNN Layers There are many variants of RNN
# especially for tasks that are hard to handle with RNN layers. _ layers, but we focus on RNNs that can be written as
# Wang et al. (2025b) adopt a simple pipeline and attention
# layer selection scheme and show severe performance degra- ge =x:Wy, ki=x:We, vVe=xiWe, (4)
# dation. More recent works choose which attention layers to S; = F:S:_-1 + k/ vz € R&™**, (5)
# retain more sophistically. Yang et al. (2026) use the output _ T d
# distribution shift when replacing an attention layer with an ye=a:SiWe CR’, (6)
# aes to ee poat, imponance of oaney on lay- where F; € R@*4* is named the transition matrix and
# STS. OSmnO et a - ( ) propose a redundancy metric is a function of x;. The above formulas include state-of-
# for determining importance, and Gu et al. (2025) rely on the-art RNN variants such as Mamba2 (Dao & Gu, 2024),
# the performance drop on certain tasks. Finally, KL-guided Gated DeltaNet (Yang et al., 2025b), etc. To enable fast
# on poses using KL. ivergence from the teacher model ae parallelization, F; is typically a diagonal matrix or rank-1
# 7 matrix (Yang et al., 2024; 2025b). S; is named the recurrent
# the importance metric and requires a thorough search that state! “ d Ea (5) and (6) are ee d the update rule and
# repeatedly reruns a distillation process for every layer. the query ru le, respectively.
# Table 1 lists previous distillation works. These works typi-
# cally use more than 10B training tokens and have poor recall 3.1. The Impact of Attention Layer Selection when
# performance compared to Transformer models, especially Distilling Transformers into Hybrids
# ] texts. I trast, distillati d . eqds . .
# requires ‘ust 538 vokene ae d or archi tee ne hae snuck When distilling Transformer models into hybrid models, one
# stronger long-context performance thanks to its superior important question is how to select which attention layers
# lencth veneralization to remain unconverted, i1.e., how to determine the optimal
# omg Zaten for maximizing model performance, without increasing
# i. . the number of attention layers |Zatn| (since efficiency is
# 3. Preliminaries negatively correlated with |Zatn|). Previous works have
# Notations All models involved in this study, including identified that RNN models underperform attention models
# both Transformer and hybrid models, consist of a stack of on recall-intensive tasks (Yang et al., 2025b, Shen et al.,
# L layers, and the I-th layer can be formalized as 2025; Jelassi et al., 2024); thus, our objective is to identify
# , which attention layers are most important for modeling
# H® = Mixer (x) 4x) recall abilities and leave them unconverted.
# = Mixer ;
# 1
# xO = mpp (H) 4 HO, () 3.2. The Importance of Position Encoding for Language
# Modeling and Length Generalization
# where X) = [x],---, x} ]' ce RTX4 denotes the T For attention-based models, it is common to inject posi-
# d-dimensional output embeddings. In an RNN-attention —_ tional information into the model via RoPE, which ap-
# hybrid model, the set of attention layers is specified by _ Plies a position-dependent rotation to Q and K. Although
# Latin € {latn,i | i= 1,+++ , Latn}, where Lat is the number RoPE typically improves language modeling performance of
# of attention layers and latin; € {1,--- , L} is the index of Transformer models, attention without RoPE (a.k.a., NoPE),
# the i-th attention layer. The mixers are defined as exhibits superior training-free length generalization (Kazem-
# nejad et al., 2023; Wang et al., 2024; Puvvada et al., 2025).
# lo; —
# Mixer — ATIN®  ifle Lauin, (2) Here, we ignore the multi-head mechanism for simplicity.
# RNN otherwise. ‘Also named hidden state in some papers.
# 3
# (<PIL.Image.Image image mode=L size=3825x4950>,
#       level  page_num  block_num  par_num  line_num  word_num  left   top  \
#  4        5         1          1        1         1         1  1427   298
#  5        5         1          1        1         1         2  1615   298
#  6        5         1          1        1         1         3  1791   298
#  7        5         1          1        1         1         4  2032   299
#  8        5         1          1        1         1         5  2172   298
#  ..     ...       ...        ...      ...       ...       ...   ...   ...
#  822      5         1          1        1        57         6  2471  4438
#  823      5         1          1        1        57         7  2591  4430
#  824      5         1          1        1        57         8  2650  4443
#  825      5         1          1        1        57         9  2781  4443
#  827      5         1          1        1        58         1  1852  4582
#
#       width  height       conf       text
#  4      173      51  96.580170     Hybrid
#  5      161      41  96.187836     Linear
#  6      226      41  95.850311  Attention
#  7      123      40  96.540535       Done
#  8      132      52  95.995972      Right
#  ..     ...     ...        ...        ...
#  822    104      31  96.918716      state
#  823     42      39  96.959427         in
#  824    115      26  96.876190       some
#  825    156      38  96.055878    papers.
#  827     25      44  96.933472          3
#
#  [767 rows x 12 columns],
#  "Hybrid Linear Attention Done Right\nadopted NoPE in both attention and RNN layers. Incontrast, | Softmax Attention Layers In Transformer, the mixer\nour model employs a novel PE scheme and achieves better —_ layer uses softmax attention, which can be written as*\nlong-context performance than typical PE methods found in\nexisting hybrid models. Q=XW,, K=XW;, V=XW,,\n1 (3)\nY = soft —QK'oM)vw}\nDistilling Transformers into Hybrid Models Many sommes (. /dy, QK' © ) °°\nworks focus on converting Transformers into pure RNN\nmodels via distillation (Kasai et al., 2021; Bick et al., 2025; | where W,,W;,W,,W. © R**% are learnable param-\nZhang et al., 2025; Goldstein et al., 2025), but converting eters, and M is the attention mask. We use row-vector\nTransformers into hybrid models remains underexplored. _tepresentation, so x'x denotes an outer product.\nWhen distilling into hybrids, choosing which attention layer\nto convert to RNN is critical for maintaining performance, | Modern RNN Layers There are many variants of RNN\nespecially for tasks that are hard to handle with RNN layers. _ layers, but we focus on RNNs that can be written as\nWang et al. (2025b) adopt a simple pipeline and attention\nlayer selection scheme and show severe performance degra- ge =x:Wy, ki=x:We, vVe=xiWe, (4)\ndation. More recent works choose which attention layers to S; = F:S:_-1 + k/ vz € R&™**, (5)\nretain more sophistically. Yang et al. (2026) use the output _ T d\ndistribution shift when replacing an attention layer with an ye=a:SiWe CR’, (6)\naes to ee poat, imponance of oaney on lay- where F; € R@*4* is named the transition matrix and\nSTS. OSmnO et a - ( ) propose a redundancy metric is a function of x;. The above formulas include state-of-\nfor determining importance, and Gu et al. (2025) rely on the-art RNN variants such as Mamba2 (Dao & Gu, 2024),\nthe performance drop on certain tasks. Finally, KL-guided Gated DeltaNet (Yang et al., 2025b), etc. To enable fast\non poses using KL. ivergence from the teacher model ae parallelization, F; is typically a diagonal matrix or rank-1\n7 matrix (Yang et al., 2024; 2025b). S; is named the recurrent\nthe importance metric and requires a thorough search that state! “ d Ea (5) and (6) are ee d the update rule and\nrepeatedly reruns a distillation process for every layer. the query ru le, respectively.\nTable 1 lists previous distillation works. These works typi-\ncally use more than 10B training tokens and have poor recall 3.1. The Impact of Attention Layer Selection when\nperformance compared to Transformer models, especially Distilling Transformers into Hybrids\n] texts. I trast, distillati d . eqds . .\nrequires ‘ust 538 vokene ae d or archi tee ne hae snuck When distilling Transformer models into hybrid models, one\nstronger long-context performance thanks to its superior important question is how to select which attention layers\nlencth veneralization to remain unconverted, i1.e., how to determine the optimal\nomg Zaten for maximizing model performance, without increasing\ni. . the number of attention layers |Zatn| (since efficiency is\n3. Preliminaries negatively correlated with |Zatn|). Previous works have\nNotations All models involved in this study, including identified that RNN models underperform attention models\nboth Transformer and hybrid models, consist of a stack of on recall-intensive tasks (Yang et al., 2025b, Shen et al.,\nL layers, and the I-th layer can be formalized as 2025; Jelassi et al., 2024); thus, our objective is to identify\n, which attention layers are most important for modeling\nH® = Mixer (x) 4x) recall abilities and leave them unconverted.\n= Mixer ;\n1\nxO = mpp (H) 4 HO, () 3.2. The Importance of Position Encoding for Language\nModeling and Length Generalization\nwhere X) = [x],---, x} ]' ce RTX4 denotes the T For attention-based models, it is common to inject posi-\nd-dimensional output embeddings. In an RNN-attention —_ tional information into the model via RoPE, which ...

# %% [markdown]
# ### Observations
#
# When processing pages with mathematical expressions and formulas, OCR quality degrades noticeably:
#
# - **Mathematical formulas are incorrectly parsed**
#   - Symbols, subscripts and superscripts are misinterpreted or lost.
#   - Expressions are flattened into invalid text (e.g. matrices, fractions, attention equations).
#
# - **Severe symbol corruption**
#   - Mathematical operators (e.g. ×, ⊤, √, subscripts) are replaced by random characters.
#   - Variable names and notation become inconsistent or unreadable.
#
# - **Loss of semantic meaning**
#   - Extracted formulas cannot be reliably reconstructed or interpreted.
#   - The resulting text is unsuitable for downstream LLMs or mathematical reasoning tasks.
